# %% [markdown]
# Data Loading / Reading
# Data Exploration

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv (r"C:\Electric_Vehicle_Population_Data.csv")

# %%
df.head()
# Out:
#    VIN (1-10)     County     City State  Postal Code  Model Year    Make  \
# 0  5YJSA1E22K       King  Seattle    WA      98112.0        2019   TESLA
# 1  3MW39FS05R     Yakima   Zillah    WA      98953.0        2024     BMW
# 2  1N4AZ0CP0F       King     Kent    WA      98031.0        2015  NISSAN
# 3  5YJSA1H20F  Snohomish  Bothell    WA      98012.0        2015   TESLA
# 4  JTMAB3FV1N     Yakima   Yakima    WA      98908.0        2022  TOYOTA
#
#         Model                   Electric Vehicle Type  \
# 0     MODEL S          Battery Electric Vehicle (BEV)
# 1        330E  Plug-in Hybrid Electric Vehicle (PHEV)
# 2        LEAF          Battery Electric Vehicle (BEV)
# 3     MODEL S          Battery Electric Vehicle (BEV)
# 4  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             270
# ...

# %%
df.tail()
# Out:
#         VIN (1-10)        County       City State  Postal Code  Model Year  \
# 191402  5YJ3E1EA0K        Pierce     Sumner    WA      98390.0        2019
# 191403  JN1BF0BA7P        Pierce   Wilkeson    WA      98396.0        2023
# 191404  7SAYGDEE4R          King  Fall City    WA      98024.0        2024
# 191405  7SAXCBE65N  Grays Harbor   Aberdeen    WA      98520.0        2022
# 191406  7SAYGAEEXP        Benton   Richland    WA      99352.0        2023
#
#           Make    Model           Electric Vehicle Type  \
# 191402   TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 191403  NISSAN    ARIYA  Battery Electric Vehicle (BEV)
# 191404   TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 191405   TESLA  MODEL X  Battery Electric Vehicle (BEV)
# 191406   TESLA  MODEL Y  Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 191402            Clean Alternative Fuel Vehicle Eligible             220
# ...

# %%
column_name = "Postal Code"
unique_values = df["Postal Code"].unique()
print(f"Unique values in column '{column_name}':")
print(unique_values)
# Out:
# Unique values in column 'Postal Code':
# [98112. 98953. 98031. 98012. 98908. 98052. 98597. 98370. 98501. 98367.
#  98030. 98155. 98512. 98296. 98007. 98011. 98513. 98902. 98110. 98115.
#  98292. 98102. 98311. 98366. 98502. 98021. 98087. 98901. 98506. 98903.
#  98056. 98272. 98258. 99163. 98134. 98039. 98042. 98116. 98312. 98310.
#  98516. 98275. 98118. 98392. 98383. 98346. 98936. 99362. 98070. 98922.
#  98208. 98802. 98204. 98020. 98848. 98801. 98053. 98837. 98005. 98232.
#  99114.    nan 98942. 98273. 98144. 98822. 98037. 98221. 98290. 98022.
#  98203. 98271. 98925. 98201. 98036. 98043. 98026. 98001. 85338. 98034.
#  98177. 98662. 98072. 98059. 98685. 98188. 98103. 98033. 98008. 98040.
#  98125. 98032. 98606. 98951. 98359. 98101. 98626. 98932. 98004. 98664.
#  98023. 98661. 98109. 98045. 98119. 98604. 98055. 98133. 98935. 98683.
#  98027. 98365. 98029. 98270. 98146. 98122. 98006. 98166. 98277. 98632.
#  98074. 98107. 98168. 98117. 98019. 98607. 98686. 98092. 98684. 98028.
# ...

# %%
print(" Attributes in Data")
for cols in df.columns:
    print(cols)
# Out:
#  Attributes in Data
# VIN (1-10)
# County
# City
# State
# Postal Code
# Model Year
# Make
# Model
# Electric Vehicle Type
# Clean Alternative Fuel Vehicle (CAFV) Eligibility
# Electric Range
# Base MSRP
# Legislative District
# DOL Vehicle ID
# Vehicle Location
# Electric Utility
# 2020 Census Tract

# %%
print(df.count())
# Out:
# VIN (1-10)                                           191407
# County                                               191403
# City                                                 191403
# State                                                191407
# Postal Code                                          191403
# Model Year                                           191407
# Make                                                 191407
# Model                                                191407
# Electric Vehicle Type                                191407
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    191407
# Electric Range                                       191407
# Base MSRP                                            191407
# Legislative District                                 190993
# DOL Vehicle ID                                       191407
# Vehicle Location                                     191399
# Electric Utility                                     191403
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191407 entries, 0 to 191406
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         191407 non-null  object
#  1   County                                             191403 non-null  object
#  2   City                                               191403 non-null  object
#  3   State                                              191407 non-null  object
#  4   Postal Code                                        191403 non-null  float64
#  5   Model Year                                         191407 non-null  int64
#  6   Make                                               191407 non-null  object
#  7   Model                                              191407 non-null  object
# ...

# %%
df.isnull()
# Out:
#         VIN (1-10)  County   City  State  Postal Code  Model Year   Make  \
# 0            False   False  False  False        False       False  False
# 1            False   False  False  False        False       False  False
# 2            False   False  False  False        False       False  False
# 3            False   False  False  False        False       False  False
# 4            False   False  False  False        False       False  False
# ...            ...     ...    ...    ...          ...         ...    ...
# 191402       False   False  False  False        False       False  False
# 191403       False   False  False  False        False       False  False
# 191404       False   False  False  False        False       False  False
# 191405       False   False  False  False        False       False  False
# 191406       False   False  False  False        False       False  False
#
#         Model  Electric Vehicle Type  \
# 0       False                  False
# ...

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 4
# City                                                   4
# State                                                  0
# Postal Code                                            4
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 414
# DOL Vehicle ID                                         0
# Vehicle Location                                       8
# Electric Utility                                       4
# ...

# %%
df.shape
# Out:
# (191407, 17)

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (190989, 17)

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 0
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     0
# 2020 Census Tract                                    0
# dtype: int64
